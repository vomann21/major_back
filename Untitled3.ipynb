# %%
import numpy as np
import pandas as pd
phone_df = pd.read_csv('flip_phones.csv')

# %%
phone_df
# Out:
#                                          title  \
# 0           Apple iPhone 14 (Midnight, 128 GB)
# 1               Apple iPhone 15 (Blue, 128 GB)
# 2       SAMSUNG Galaxy F04 (Opal Green, 64 GB)
# 3              Apple iPhone 15 (Black, 128 GB)
# 4          Apple iPhone 14 (Starlight, 128 GB)
# ...                                        ...
# 12019      vivo T2x 5G (Glimmer Black, 128 GB)
# 12020     MOTOROLA g54 5G (Mint Green, 256 GB)
# 12021        vivo T2x 5G (Aurora Gold, 128 GB)
# 12022        vivo T2x 5G (Marine Blue, 128 GB)
# 12023  MOTOROLA g54 5G (Midnight Blue, 128 GB)
#
#                                                    image    price  \
# 0      https://rukminim2.flixcart.com/image/312/312/x...  ₹58,999
# 1      https://rukminim2.flixcart.com/image/312/312/x...  ₹72,999
# 2      https://rukminim2.flixcart.com/image/312/312/x...   ₹7,999
# 3      https://rukminim2.flixcart.com/image/312/312/x...  ₹73,999
# ...

# %%
num_rows_unique = phone_df.shape[0]
print(num_rows_unique)
# Out:
# 12024
