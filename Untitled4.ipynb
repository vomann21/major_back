# %%
import pandas as pd
df=pd.read_csv('flip_laptop.csv')

# %%
print(df.head(10))
# Out:
#                          title  \
# 0  WINGS Nuvobook V1 Aluminium
# 1           ASUS ROG Strix G15
# 2       Apple 2020 Macbook Air
# 3       Apple 2020 Macbook Air
# 4       ASUS Vivobook 15 Intel
# 5            MSI Modern 14 AMD
# 6           DELL Intel Core i3
# 7             MSI Bravo 15 AMD
# 8            HP 14s Intel Core
# 9          ASUS TUF Gaming F15
#
#                                                image    price  \
# 0  https://rukminim2.flixcart.com/image/312/312/x...  ₹27,990
# 1  https://rukminim2.flixcart.com/image/312/312/x...  ₹77,990
# 2  https://rukminim2.flixcart.com/image/312/312/k...  ₹83,990
# 3  https://rukminim2.flixcart.com/image/312/312/k...  ₹83,990
# 4  https://rukminim2.flixcart.com/image/312/312/x...  ₹29,990
# 5  https://rukminim2.flixcart.com/image/312/312/x...  ₹31,990
# 6  https://rukminim2.flixcart.com/image/312/312/l...  ₹35,490
# 7  https://rukminim2.flixcart.com/image/312/312/x...  ₹47,990
# ...

# %%
import pandas as pd

# Assuming you have a DataFrame named 'df'
# df = pd.DataFrame({...})

# Check for duplicate rows
duplicate_rows = df[df.duplicated()]

# Display the duplicate rows
print("Duplicate Rows except first occurrence:")
print(duplicate_rows)
print(len(duplicate_rows))

# If you want to keep only the first occurrence of each duplicate row, you can use the keep parameter
# For example:
# df_no_duplicates = df.drop_duplicates(keep='first')

# If you want to keep only the last occurrence of each duplicate row, you can use keep='last'
# For example:
# df_no_duplicates = df.drop_duplicates(keep='last')
print(len(df))
# Out:
# Duplicate Rows except first occurrence:
# Empty DataFrame
# Columns: [title, image, price, description, brand, platform, type, product_link]
# Index: []
# 0
# 1992

# %%
import pandas as pd

# Assuming you have a DataFrame named 'df'
# df = pd.DataFrame({...})

# Remove duplicate rows and keep only the first occurrence
df_2 = df.drop_duplicates(keep='first')

# Display the DataFrame without duplicates
print(df_2)
print(len(df_2))
# Out:
#                              title  \
# 0      WINGS Nuvobook V1 Aluminium
# 1               ASUS ROG Strix G15
# 2           Apple 2020 Macbook Air
# 3           Apple 2020 Macbook Air
# 4           ASUS Vivobook 15 Intel
# ...                            ...
# 1987        ASUS Vivobook 15 Intel
# 1988   WINGS Nuvobook S2 Aluminium
# 1989  WINGS Nuvobook Pro Aluminium
# 1990       ASUS Vivobook 14 (2023)
# 1991        ASUS Vivobook S14 OLED
#
#                                                   image    price  \
# 0     https://rukminim2.flixcart.com/image/312/312/x...  ₹27,990
# 1     https://rukminim2.flixcart.com/image/312/312/x...  ₹77,990
# 2     https://rukminim2.flixcart.com/image/312/312/k...  ₹83,990
# 3     https://rukminim2.flixcart.com/image/312/312/k...  ₹83,990
# 4     https://rukminim2.flixcart.com/image/312/312/x...  ₹29,990
# ...                                                 ...      ...
# 1987  https://rukminim2.flixcart.com/image/312/312/x...  ₹27,990
# ...

# %%
import pandas as pd

# Assuming you have a DataFrame named 'new_df'
# new_df = pd.DataFrame({...})

# Specify the column name you want to remove
column_to_remove = 'image'

# Use the drop method to remove the specified column
new_df = df.drop(column_to_remove, axis=1)

column_to_remove = 'product_link'

# Use the drop method to remove the specified column
new_df2 = new_df.drop(column_to_remove, axis=1)

# Display the DataFrame after removing the column
print(len(new_df2))
# Out:
# 1992

# %%
import pandas as pd

# Assuming you have a DataFrame named 'df'
# df = pd.DataFrame({...})

# Remove duplicate rows and keep only the first occurrence
df_2 = new_df2.drop_duplicates(keep='first')

# Display the DataFrame without duplicates
print(df_2)
print(len(df_2))
# Out:
#                               title      price  \
# 0       WINGS Nuvobook V1 Aluminium    ₹27,990
# 1                ASUS ROG Strix G15    ₹77,990
# 2            Apple 2020 Macbook Air    ₹83,990
# 3            Apple 2020 Macbook Air    ₹83,990
# 4            ASUS Vivobook 15 Intel    ₹29,990
# 5                 MSI Modern 14 AMD    ₹31,990
# 6                DELL Intel Core i3    ₹35,490
# 7                  MSI Bravo 15 AMD    ₹47,990
# 8                 HP 14s Intel Core    ₹35,990
# 9               ASUS TUF Gaming F15    ₹47,990
# 10      WINGS Nuvobook S2 Aluminium    ₹25,990
# 11     WINGS Nuvobook Pro Aluminium    ₹37,990
# 12              Acer One Intel Core    ₹26,990
# 13           ASUS Vivobook S14 OLED    ₹65,990
# 14           ASUS Vivobook 15 Intel    ₹40,990
# 15                   HP AMD Ryzen 3    ₹33,890
# 18             Lenovo Intel Core i7    ₹49,990
# 19           ASUS Vivobook 15 Intel    ₹27,990
# 22           Apple 2020 Macbook Air    ₹83,990
# ...
