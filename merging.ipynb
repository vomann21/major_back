# %%
import pandas as pd
import numpy as np

amazon_product = pd.read_csv('amazon_product_reviews.csv')
amazon_product2 = pd.read_csv('amazon_product_reviews2.csv')
amazon_product3 = pd.read_csv('amazon_product_reviews3.csv')
amazon_product4 = pd.read_csv('amazon_product_reviews4.csv')
amazon_product5 = pd.read_csv('amazon_product_reviews5.csv')
amazon_product6 = pd.read_csv('amazon_product_reviews6.csv')
amazon_product7 = pd.read_csv('amazon_product_reviews7.csv')
amazon_product8 = pd.read_csv('amazon_product_reviews8.csv')
amazon_product9 = pd.read_csv('amazon_product_reviews9.csv')
amazon_product10 = pd.read_csv('amazon_product_reviews10.csv')
amazon_product11 = pd.read_csv('amazon_product_reviews11.csv')
amazon_product12 = pd.read_csv('amazon_product_reviews12.csv')
amazon_product13 = pd.read_csv('amazon_product_reviews13.csv')
amazon_product14 = pd.read_csv('amazon_product_reviews14.csv')
amazon_product15 = pd.read_csv('amazon_product_reviews15.csv')
amazon_product16 = pd.read_csv('amazon_product_reviews16.csv')
amazon_product17 = pd.read_csv('amazon_product_reviews17.csv')
amazon_product18 = pd.read_csv('amazon_product_reviews18.csv')
amazon_product19 = pd.read_csv('amazon_product_reviews19.csv')
amazon_product20 = pd.read_csv('amazon_product_reviews20.csv')
amazon_product21 = pd.read_csv('amazon_product_reviews21.csv')
amazon_product22 = pd.read_csv('amazon_product_reviews22.csv')
amazon_product23 = pd.read_csv('amazon_product_reviews23.csv')
amazon_product24 = pd.read_csv('amazon_product_reviews24.csv')
amazon_product25 = pd.read_csv('amazon_product_reviews25.csv')
amazon_product26 = pd.read_csv('amazon_product_reviews26.csv')
amazon_product27 = pd.read_csv('amazon_product_reviews27.csv')
amazon_product28 = pd.read_csv('amazon_product_reviews28.csv')
amazon_product29 = pd.read_csv('amazon_product_reviews29.csv')
amazon_product30 = pd.read_csv('amazon_product_reviews30.csv')
amazon_product31 = pd.read_csv('amazon_product_reviews31.csv')


combined_df = pd.concat([amazon_product,amazon_product2,amazon_product3,amazon_product4,amazon_product5,amazon_product6,amazon_product7,amazon_product8,amazon_product9,amazon_product10,amazon_product11,amazon_product12,amazon_product13,amazon_product14,amazon_product15,amazon_product16,amazon_product17,amazon_product18,amazon_product19,amazon_product20,amazon_product21,amazon_product22,amazon_product23,amazon_product24,amazon_product25,amazon_product26,amazon_product27,amazon_product28,amazon_product29,amazon_product30], axis=0, ignore_index=True)
combined_df
# Out:
#                              user_name  \
# 0                       Nachiket Patil
# 1                        sachin bondre
# 2     Rishabh Dwivedi Rishabh Dwivedi
# 3       Amazon CustomerAmazon Customer
# 4                     sneha latha kase
# ...                                ...
# 2831                      Ritesh Yadav
# 2832                             Proxy
# 2833                         Tushar B.
# 2834                   Rohit Choudhary
# 2835                    Praveen Rajput
#
#                                            small_review  \
# 0                                      Very good laptop
# 1     Worth Buying for Lightweight office as well as...
# 2                                         Laptop review
# 3                       Worst product and worst support
# 4                                                  Good
# ...                                                 ...
# 2831                                  About the Product
# ...

# %%
combined_df.to_csv('merged_review.csv', index=False)

print("DataFrame converted to CSV successfully.")
# Out:
# DataFrame converted to CSV successfully.
